# %%
import pandas as pd

import numpy as np

import os

import re

from datetime import datetime

df = pd.read_csv('pulak1.csv')
print(df)
# Out:
#                                                    text           name
# 0                                      I mean you could          Pulak
# 1                           What’s wrong with an iPhone          Pulak
# 2                         Get op6 agar itna problem hai          Pulak
# 3             I mean... The iPhone model range rn sucks  Ishnoor Singh
# 4      And the new models coming out next month aren...  Ishnoor Singh
# 5                                               Dekh lo          Pulak
# 6                     You can try convincing for an op6          Pulak
# 7             It’ll be easier considering aunty has one          Pulak
# 8                                             It's over  Ishnoor Singh
# 9                             I got em back to no Apple  Ishnoor Singh
# 10                                            Nice nice          Pulak
# 11                                             Good job          Pulak
# 12             Then it should be fairly straightforward          Pulak
# 13                                                 Yeah  Ishnoor Singh
# 14                            So blackberry with XPS 15  Ishnoor Singh
# 15                                         Haan perfect          Pulak
# 16                          That was the one you wanted          Pulak
# 17                                               Hahaha  Ishnoor Singh
# 18                                                  Yup  Ishnoor Singh
# 19                                     Way too easy tho  Ishnoor Singh
# 20                                                  😂😂😂  Ishnoor Singh
# 21                                            Bwahahaha          Pulak
# 22                        How long did it even take you          Pulak
# 23                                             Not long  Ishnoor Singh
# 24                                   Lol how's college?  Ishnoor Singh
# 25                                           Thought so          Pulak
# 26                                       So far so good          Pulak
# 27             Classes haven’t started yet so let’s see          Pulak
# 28                               Gosh.... You're scared  Ishnoor Singh
# 29                                                  Yep          Pulak
# ...                                                 ...            ...
# 5704                              How was the hackathon          Pulak
# 5705                         Had spring quarter started          Pulak
# 5706                                                Bad  Ishnoor Singh
# 5707                                  You tell😉😉😉😉😉😉😉😉😉  Ishnoor Singh
# 5708                                         And bro...  Ishnoor Singh
# 5709   Wither workout and gain muscle or eat more an...  Ishnoor Singh
# 5710                  You look like a wimpy kid cartoon  Ishnoor Singh
# 5711                                            Lol why          Pulak
# 5712                        Did you his do that thingie          Pulak
# 5713                                      With markdown          Pulak
# 5714                                  Life is sad again          Pulak
# 5715                                                😂😂😂          Pulak
# 5716                                Lmaooo not true man          Pulak
# 5717               Gain muscle I will try in the summer          Pulak
# 5718   What’s your plan now? Kuch fonalise hua for s...          Pulak
# 5719                                      It is true...  Ishnoor Singh
# 5720                                            Noooope          Pulak
# 5721                                             It  is  Ishnoor Singh
# 5722                                            Noooope          Pulak
# 5723                                                Yup  Ishnoor Singh
# 5724        Looks like wind could break you into pieces  Ishnoor Singh
# 5725   Or biology instructors could Use you for skel...  Ishnoor Singh
# 5726                                              https  Ishnoor Singh
# 5727                     Wind is a scientific construct          Pulak
# 5728                                Anarchy all the way          Pulak
# 5729   Skeletons are a scientific construct anarchy ...          Pulak
# 5730                                        Tf was that          Pulak
# 5731   Also there’s a Michael Jackson thriller parod...          Pulak
# 5732                Have you been talking with vaibhav?  Ishnoor Singh
# 5733                                                Wtf  Ishnoor Singh
#
# [5734 rows x 2 columns]

# %%
df.head()
# Out:
#                                                 text           name
# 0                                   I mean you could          Pulak
# 1                        What’s wrong with an iPhone          Pulak
# 2                      Get op6 agar itna problem hai          Pulak
# 3          I mean... The iPhone model range rn sucks  Ishnoor Singh
# 4   And the new models coming out next month aren...  Ishnoor Singh

# %%
r = df["name"]
print (r)
# Out:
# 0               Pulak
# 1               Pulak
# 2               Pulak
# 3       Ishnoor Singh
# 4       Ishnoor Singh
# 5               Pulak
# 6               Pulak
# 7               Pulak
# 8       Ishnoor Singh
# 9       Ishnoor Singh
# 10              Pulak
# 11              Pulak
# 12              Pulak
# 13      Ishnoor Singh
# 14      Ishnoor Singh
# 15              Pulak
# 16              Pulak
# 17      Ishnoor Singh
# 18      Ishnoor Singh
# 19      Ishnoor Singh
# 20      Ishnoor Singh
# 21              Pulak
# 22              Pulak
# 23      Ishnoor Singh
# 24      Ishnoor Singh
# 25              Pulak
# 26              Pulak
# 27              Pulak
# 28      Ishnoor Singh
# 29              Pulak
#             ...
# 5704            Pulak
# 5705            Pulak
# 5706    Ishnoor Singh
# 5707    Ishnoor Singh
# 5708    Ishnoor Singh
# 5709    Ishnoor Singh
# 5710    Ishnoor Singh
# 5711            Pulak
# 5712            Pulak
# 5713            Pulak
# 5714            Pulak
# 5715            Pulak
# 5716            Pulak
# 5717            Pulak
# 5718            Pulak
# 5719    Ishnoor Singh
# 5720            Pulak
# 5721    Ishnoor Singh
# 5722            Pulak
# 5723    Ishnoor Singh
# 5724    Ishnoor Singh
# 5725    Ishnoor Singh
# 5726    Ishnoor Singh
# 5727            Pulak
# 5728            Pulak
# 5729            Pulak
# 5730            Pulak
# 5731            Pulak
# 5732    Ishnoor Singh
# 5733    Ishnoor Singh
# Name: name, Length: 5734, dtype: object

# %%
def getWhatsAppData():

        df = pd.read_csv('pulak2.csv')

        responseDictionary = dict()

        receivedMessages = df[df['name'] != personName]

        sentMessages = df[df['name'] == personName]

        combined = pd.concat([sentMessages, receivedMessages])

        otherPersonsMessage, myMessage = "",""

        firstMessage = True

        for index, row in combined.iterrows():

            if (row['name'] != personName):

                if myMessage and otherPersonsMessage:

                    otherPersonsMessage = cleanMessage(otherPersonsMessage)

                    myMessage = cleanMessage(myMessage)

                    responseDictionary[otherPersonsMessage.rstrip()] = myMessage.rstrip()

                    otherPersonsMessage, myMessage = "",""

                otherPersonsMessage = otherPersonsMessage + str(row['text']) + " "

            else:

                if (firstMessage):

                    firstMessage = False

                    # Don't include if I am the person initiating the convo

                    continue

                myMessage = myMessage + str(row['text']) + " "

        return responseDictionary


   ###############################################
def cleanMessage(message):

  # Remove new lines within message

  cleanedMessage = message.replace('\x8f',' ').lower()

  # Deal with some weird tokens

  cleanedMessage = cleanedMessage.replace("\xc2\xa0", "")

  # Remove punctuation

  cleanedMessage = re.sub('([.,!?])','', cleanedMessage)

  # Remove multiple spaces in message

  cleanedMessage = re.sub('ðÿ˜',' ', cleanedMessage)
    
  return cleanedMessage


combinedDictionary = {}





combinedDictionary.update(getWhatsAppData())

print ('Total len of dictionary', len(combinedDictionary))



print ('Saving conversation data dictionary')

np.save('conversationDictionary.npy', combinedDictionary)
np.load("conversationDictionary.npy")


conversationFile = open('conversationData.txt', 'w')

for key,value in combinedDictionary.items():

  if (not key.strip() or not value.strip()):

    # If there are empty strings

    continue

  conversationFile.write(key.strip() + value.strip())
# Out:
# Total len of dictionary 1
# Saving conversation data dictionary
